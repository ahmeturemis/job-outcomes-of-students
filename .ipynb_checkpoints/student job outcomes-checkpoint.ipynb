# %%
import pandas as pd
import matplotlib.pyplot as plt #pyplot module used for creating different plots.we need magic to display plots inline
# %matplotlib inline              
recent_grads = pd.read_csv("recent-grads.csv") 
recent_grads.iloc[0] #displaying first row formatted as a table
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head(3) #displays first 3 rows
# Out:
#    Rank  Major_code                           Major   Total     Men  Women  \
# 0     1        2419           PETROLEUM ENGINEERING  2339.0  2057.0  282.0
# 1     2        2416  MINING AND MINERAL ENGINEERING   756.0   679.0   77.0
# 2     3        2415       METALLURGICAL ENGINEERING   856.0   725.0  131.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
# 1    Engineering    0.101852            7       640      ...              170
# 2    Engineering    0.153037            3       648      ...              133
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
# 1                   388          85           0.117241   75000  55000   90000
# 2                   340          16           0.024096   73000  50000  105000
#
# ...

# %%
recent_grads.tail(3) #displays last 3 rows
# Out:
#      Rank  Major_code                  Major   Total    Men   Women  \
# 170   171        5202    CLINICAL PSYCHOLOGY  2838.0  568.0  2270.0
# 171   172        5203  COUNSELING PSYCHOLOGY  4626.0  931.0  3695.0
# 172   173        3501        LIBRARY SCIENCE  1098.0  134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 170      ...              648                  1293         368
# 171      ...              965                  2738         214
# 172      ...              237                   410          87
#
#      Unemployment_rate  Median  P25th  P75th  College_jobs  Non_college_jobs  \
# 170           0.149048   25000  25000  40000           986               870
# ...

# %%
recent_grads.describe() #generate summary statistics for all of the numeric columns
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = len(recent_grads.index) #calculate index of dataframe and display number of rows
print(raw_data_count)
# Out:
# 173

# %%
recent_grads = recent_grads.dropna() #drop rows containing missing values

# %%
cleaned_data_count = len(recent_grads.index) #after cleaning rows contains missing values.we have one less rows than before
print(cleaned_data_count)
# Out:
# 172

# %%
recent_grads.plot(x="Sample_size",y="Employed",kind="scatter") #plot method has x,y for specify to define axes.kind specify type of plot

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', figsize=(5,10)) #same as above

# %%
ax = recent_grads.plot(x='Sample_size', y='Employed', kind='scatter') #same as above
ax.set_title('Employed vs. Sample_size')

# %%
recent_grads.plot(x="Sample_size",y="Median",kind="scatter")

# %%
recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind="scatter")

# %%
recent_grads.plot(x="Full_time",y="Median",kind="scatter") #Median earnings of full-time, year-round workers vs working 35 hours or more

# %%
recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind="scatter")  #Women as share of total vs Unemployed / (Unemployed + Employed)

# %%
recent_grads.plot(x="Men",y="Median",kind="scatter") #Male graduates vs Median earnings of full-time, year-round workers

# %%
recent_grads.plot(x="Women",y="Median",kind="scatter") #Female graduates vs Median earnings of full-time, year-round workers

# %%
recent_grads['Sample_size'].hist(bins=25, range=(0,5000)) #use series.hist() to control the binning strategy of histogram

# %%
cols = ["Sample_size","Median","Employed","Full_time","ShareWomen","Unemployment_rate","Men","Women"]
fig=plt.figure(figsize=(5,16))
for each in range(1,5):
    ax = fig.add_subplot(4,1,each)
    ax = recent_grads[cols[each]].plot(kind="hist",rot=40)

# %%
cols = ["Sample_size","Median","Employed","Full_time","ShareWomen","Unemployment_rate","Men","Women"]
fig=plt.figure(figsize=(5,12))
for each in range(4,8):
    ax = fig.add_subplot(4,1,each-3)
    ax = recent_grads[cols[each]].plot(kind="hist",rot=40)

# %%
recent_grads['Median'].hist(bins=25, range=(0,100000))

# %%
from pandas.plotting import scatter_matrix 
scatter_matrix(recent_grads[["Sample_size","Median"]],figsize=(10,10)) # scatter_matrix used for few columns.hard to read and process many columns with it
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000C90128A240>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000C90176BAC8>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]],figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000C901A70B70>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000C901F305F8>]], dtype=object)

# %%
recent_grads[:5]['Women'].plot(kind='bar') #bar plot is using first 5 value in women column

# %%
recent_grads[:5].plot.bar(x='Major', y='Women') # with dataframe.plot.bar we use x parameter to specify the labels and y parameter specify the data for the bar

# %%
recent_grads[:5].plot.bar(x='Major', y='Median') # dataframe.plot.bar is so easy to use and understand

# %%
recent_grads[:5].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[len(recent_grads)-10:]["Unemployment_rate"].plot(kind="bar")

# %%
recent_grads[0:10]["Unemployment_rate"].plot(kind="bar")

# %%
recent_grads[0:10].plot.bar(x="Major",y="Unemployment_rate")

# %%
recent_grads[len(recent_grads)-10:].plot.bar(x="Major",y="Unemployment_rate")

# %%
recent_grads[len(recent_grads)-10:].plot.bar(x="Major",y="ShareWomen")

# %%
recent_grads[0:10].plot.bar(x="Major",y="ShareWomen")

# %%
recent_grads[0:10].plot.bar(x="Major",y=["Men","Women"]) #merge two columns to research difference better

# %%
fig, ax=plt.subplots()
ax.boxplot(recent_grads["Median"])
ax.set_xticklabels(["Median"])

# %%
fig, ax=plt.subplots()
ax.boxplot(recent_grads["Unemployment_rate"])
ax.set_xticklabels(["Unemployment_rate"])
